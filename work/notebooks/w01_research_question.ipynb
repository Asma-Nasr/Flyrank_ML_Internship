# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why

# %% [markdown]
# I’m choosing the Refresh / Content Opportunity Scoring lane. I want to rank content pages by which ones look most worth reviewing first for refresh or optimization. This is a good fit for the starter dataset because there are many pages with non-zero demand and a meaningful share of pages showing declining trend direction, so a ranked queue could help an editor spend time where it is most likely to matter.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# My provisional question is: Which pages should a content editor review first for refresh or optimization?
#
# - Unit of analysis: one content page
# - Output: a ranked list or score for pages to review
# - Action: a content editor or SEO specialist reviews the top-ranked pages and decides whether to refresh, update, or improve them
# - Cost of a wrong recommendation: wasted review time, missed opportunity on a page that actually needed attention, and slower response to real refresh needs
# - Why data or ML can help: there are too many pages for manual triage, and the patterns of age, position, traffic, and trend direction may signal which pages are most worth attention even when the signal is not obvious by eye

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
df = pd.read_csv('../../data/raw/content_refresh_anonymized.csv')

# 2-3 concrete numbers that make this lane look worth the next 7 weeks
print("Rows in starter dataset:", len(df))
print("Pages with impressions > 0:", int((df["impressions_90d"] > 0).sum()))
print("Pages with sessions > 0:", int((df["sessions_90d"] > 0).sum()))
print("Declining pages:", int((df["trend_direction"] == "down").sum()))
print("Median content age (days):", round(float(df["content_age_days"].median()), 2))
print("Median CTR:", round(float(df["ctr"].median()), 4))
print("Median avg position:", round(float(df["avg_position"].median()), 2))
# Out:
# Rows in starter dataset: 30000
# Pages with impressions > 0: 30000
# Pages with sessions > 0: 30000
# Declining pages: 16262
# Median content age (days): 236.0
# Median CTR: 0.07
# Median avg position: 10.8

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# I can claim that the starter dataset contains many pages with measured search demand and that a non-trivial share of pages are labeled as declining, which makes a refresh queue plausible. I can also claim that a simple ranking model could be built from observable signals such as traffic, age, position, and trend direction.
#
# I cannot claim that this proves a causal effect of refreshing a page, nor that the model can predict the future perfectly. This work is decision-support and directional, not causal proof or a guarantee that a page will improve if updated.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
